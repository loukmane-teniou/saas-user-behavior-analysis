# %% [markdown]
# ## SaaS User Behavior Analysis – Sanity Checks
#
# This notebook performs basic behavioral sanity checks to ensure that
# the dataset reflects realistic and internally consistent user behavior.
#
# At this stage:
# - No modeling is performed
# - No assumptions are made
# - We only validate behavioral logic

# %%
import pandas as pd

df = pd.read_csv("../data/raw/realistic_user_behavior_dataset_1000.csv")

# %%
(df["clicks"] > df["visits"]).sum()
# Out:
# np.int64(0)

# %%
((df["visits"] > 0) & (df["time_spent"] == 0)).sum()
# Out:
# np.int64(0)

# %%
df["target"].value_counts()
# Out:
# target
# 0    710
# 1    290
# Name: count, dtype: int64

# %% [markdown]
# ### Sanity Check Results
#
# - No logical inconsistencies were detected
# - User actions follow realistic constraints
# - The dataset is suitable for behavioral analysis
